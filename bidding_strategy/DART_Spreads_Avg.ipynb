# %%
# =========================================================
# DART EV-window metrics + GROUP-AVERAGE (Zones vs GEN HUBs)
# Uses BASE = Path.cwd() + relative paths (NO C:\ hard-coding)
# =========================================================

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from pathlib import Path

# --- project root (where DA_LMPs_Data/ and RT_LMPs_Data/ folders live) ---
BASE = Path.cwd()

def p(*parts) -> str:
    """Build a path relative to BASE."""
    return str(BASE.joinpath(*parts))


# =========================================================
# 1) I/O helpers (robust: handles "CSV saved as .xls")
# =========================================================
def load_table(path: str) -> pd.DataFrame:
    """
    Load CSV / XLS / XLSX based on extension, but also handles the common case
    where a file is CSV text but saved with .xls extension.
    """
    fp = Path(path)
    if not fp.exists():
        raise FileNotFoundError(
            f"File not found:\n{fp}\n\nBASE is:\n{BASE}\n"
            f"Tip: make sure DA_LMPs_Data/ and RT_LMPs_Data/ are inside BASE."
        )

    pth = path.lower()

    # sniff first chunk (to detect CSV text misnamed as .xls)
    head = fp.read_bytes()[:2048]
    try:
        txt = head.decode("utf-8", errors="strict")
        if ("," in txt and "\n" in txt) or ("\t" in txt and "\n" in txt) or (";" in txt and "\n" in txt):
            delim_counts = {",": txt.count(","), "\t": txt.count("\t"), ";": txt.count(";")}
            sep = max(delim_counts, key=delim_counts.get)
            return pd.read_csv(path, sep=sep, low_memory=False)
    except Exception:
        pass

    if pth.endswith(".csv"):
        return pd.read_csv(path, low_memory=False)

    if pth.endswith((".xls", ".xlsx")):
        for engine in ["openpyxl", "xlrd"]:
            try:
                return pd.read_excel(path, engine=engine)
            except Exception:
                pass
        try:
            tables = pd.read_html(path)
            if tables:
                return tables[0]
        except Exception:
            pass
        raise ValueError(f"Excel file format cannot be determined for: {path}")

    raise ValueError(f"Unsupported file type: {path}")


def _get_time_col(df: pd.DataFrame) -> str:
    for c in [
        "interval_start_utc", "interval_start", "time", "timestamp", "datetime",
        "Interval Start", "IntervalStart", "interval_start_time_utc", "IntervalStartUTC"
    ]:
        if c in df.columns:
            return c
    for c in df.columns:
        try:
            if np.issubdtype(df[c].dtype, np.datetime64):
                return c
        except Exception:
            pass
    raise ValueError("No datetime column found. Columns:\n" + ", ".join(map(str, df.columns)))


def _pick_price_col(df: pd.DataFrame, preferred: str) -> str:
    if preferred in df.columns:
        return preferred

    lower_map = {str(c).lower(): c for c in df.columns}
    if preferred.lower() in lower_map:
        return lower_map[preferred.lower()]

    candidates = [
        "price", "lmp", "da_lmp", "rt_lmp",
        "lbmp", "mp", "value",
        "settlement_point_price", "settlement_point_price_dollar_per_mwh",
        "market_price"
    ]
    for c in candidates:
        if c in df.columns:
            return c
        if c.lower() in lower_map:
            return lower_map[c.lower()]

    numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
    for c in numeric_cols:
        if str(c).lower() not in {"year", "month", "day", "hour", "minute"}:
            return c

    raise KeyError(f"Could not find a price column. Columns are:\n{list(df.columns)}")


# =========================================================
# 2) Core: compute DART hourly (DA - RT hourly)
# =========================================================
def compute_dart_hourly(
    df_rt: pd.DataFrame,
    df_da: pd.DataFrame,
    price_col="lmp",
    clip_low=-100,
    clip_high=100,
    tz_plot="America/New_York",
    rt_hourly_method="mean",
    verbose=False,
) -> pd.DataFrame:
    rt_time_col = _get_time_col(df_rt)
    da_time_col = _get_time_col(df_da)
    rt_price_col = _pick_price_col(df_rt, price_col)
    da_price_col = _pick_price_col(df_da, price_col)

    if verbose:
        print(f"[RT] time col: '{rt_time_col}', price col: '{rt_price_col}'")
        print(f"[DA] time col: '{da_time_col}', price col: '{da_price_col}'")

    # RT
    rt = df_rt[[rt_time_col, rt_price_col]].copy()
    rt[rt_time_col] = pd.to_datetime(rt[rt_time_col], utc=True, errors="coerce")
    rt = rt.dropna(subset=[rt_time_col, rt_price_col]).sort_values(rt_time_col)
    rt["ts"] = rt[rt_time_col].dt.tz_convert(tz_plot)
    rt["price"] = pd.to_numeric(rt[rt_price_col], errors="coerce").clip(lower=clip_low, upper=clip_high)
    rt = rt.dropna(subset=["price"]).set_index("ts")[["price"]]

    if rt_hourly_method == "mean":
        rt_h = rt.resample("h").mean()
    elif rt_hourly_method == "median":
        rt_h = rt.resample("h").median()
    elif rt_hourly_method == "last":
        rt_h = rt.resample("h").last()
    else:
        raise ValueError("rt_hourly_method must be one of: mean, median, last")
    rt_h = rt_h.rename(columns={"price": f"RT_hourly_{rt_hourly_method}"})

    # DA
    da = df_da[[da_time_col, da_price_col]].copy()
    da[da_time_col] = pd.to_datetime(da[da_time_col], utc=True, errors="coerce")
    da = da.dropna(subset=[da_time_col, da_price_col]).sort_values(da_time_col)
    da["ts"] = da[da_time_col].dt.tz_convert(tz_plot)
    da["price"] = pd.to_numeric(da[da_price_col], errors="coerce").clip(lower=clip_low, upper=clip_high)
    da = da.dropna(subset=["price"]).set_index("ts")[["price"]].rename(columns={"price": "DA_hourly"})
    da_h = da.resample("h").mean()

    merged = da_h.join(rt_h, how="inner")
    merged["DA_minus_RT"] = merged["DA_hourly"] - merged[f"RT_hourly_{rt_hourly_method}"]
    return merged


def filter_charging_window(df: pd.DataFrame, start_hour=0, end_hour=6) -> pd.DataFrame:
    h = df.index.hour
    return df[(h >= start_hour) & (h < end_hour)]


def compute_ev_window_metrics(
    dart_hourly: pd.DataFrame,
    start_hour=0,
    end_hour=6,
    block_hours=6,
    cvar_alpha=0.10,
) -> dict:
    win = filter_charging_window(dart_hourly, start_hour, end_hour).copy()
    w = win["DA_minus_RT"].dropna()

    dart_hourly = dart_hourly.copy()
    dart_hourly["roll_mean"] = dart_hourly["DA_minus_RT"].rolling(block_hours).mean()
    dart_hourly["roll_std"]  = dart_hourly["DA_minus_RT"].rolling(block_hours).std()

    win["date_local"] = win.index.date
    nightly = win.groupby("date_local")["DA_minus_RT"].agg(["mean", "std", "count"])
    nightly = nightly.rename(columns={"mean": "night_mean", "std": "night_std", "count": "night_nhours"})

    mean_w = float(w.mean()) if len(w) else np.nan
    std_w  = float(w.std())  if len(w) else np.nan
    sharpe_like = (mean_w / std_w) if (std_w and std_w > 0) else np.nan

    p_pos_hour = float((w > 0).mean()) if len(w) else np.nan
    p_neg_hour = float((w < 0).mean()) if len(w) else np.nan

    roll_win = filter_charging_window(dart_hourly.dropna(subset=["roll_mean"]), start_hour, end_hour)
    roll_mean_avg = float(roll_win["roll_mean"].mean()) if len(roll_win) else np.nan
    p_pos_block   = float((roll_win["roll_mean"] > 0).mean()) if len(roll_win) else np.nan

    if len(w):
        q = w.quantile(cvar_alpha)
        cvar = float(w[w <= q].mean()) if np.isfinite(q) else np.nan
    else:
        cvar = np.nan

    if len(nightly) and nightly["night_mean"].notna().any():
        qn = nightly["night_mean"].quantile(cvar_alpha)
        cvar_night = float(nightly.loc[nightly["night_mean"] <= qn, "night_mean"].mean())
    else:
        cvar_night = np.nan

    return {
        "start_hour": start_hour,
        "end_hour": end_hour,
        "block_hours": block_hours,
        "cvar_alpha": cvar_alpha,

        "mean_dart_window": mean_w,
        "std_dart_window": std_w,
        "sharpe_like_window": sharpe_like,
        "p_positive_hour_window": p_pos_hour,
        "p_negative_hour_window": p_neg_hour,
        "cvar_hourly_window": cvar,

        "roll_mean_avg_window": roll_mean_avg,
        "p_profitable_block_window": p_pos_block,
        "cvar_nightly_mean": cvar_night,

        "dart_hourly": dart_hourly,
        "window_hourly": win,
        "nightly_blocks": nightly,
    }


# =========================================================
# 3) Build all_metrics from CASES
# =========================================================
def build_all_metrics_from_cases(
    CASES,
    START_HOUR=0,
    END_HOUR=6,
    BLOCK_HOURS=6,
    CVAR_ALPHA=0.10,
    CLIP_LOW=-100,
    CLIP_HIGH=100,
    PRICE_COL="lmp",
    RT_HOURLY_METHOD="mean",
    verbose=False,
):
    summary_rows = []
    nightly_dict = {}
    all_metrics = {}

    print("BASE =", BASE)

    for name, da_path, rt_path, tz in CASES:
        print(f"\n=== Running: {name} ===")
        print("DA:", da_path)
        print("RT:", rt_path)

        df_DA = load_table(da_path)
        df_RT = load_table(rt_path)

        dart_hourly = compute_dart_hourly(
            df_rt=df_RT,
            df_da=df_DA,
            price_col=PRICE_COL,
            clip_low=CLIP_LOW,
            clip_high=CLIP_HIGH,
            tz_plot=tz,
            rt_hourly_method=RT_HOURLY_METHOD,
            verbose=verbose,
        )

        metrics = compute_ev_window_metrics(
            dart_hourly=dart_hourly,
            start_hour=START_HOUR,
            end_hour=END_HOUR,
            block_hours=BLOCK_HOURS,
            cvar_alpha=CVAR_ALPHA,
        )

        all_metrics[name] = metrics
        nightly_dict[name] = metrics["nightly_blocks"]

        summary_rows.append({
            "iso_hub": name,
            "mean_dart_window": metrics["mean_dart_window"],
            "std_dart_window": metrics["std_dart_window"],
            "sharpe_like_window": metrics["sharpe_like_window"],
            "p_positive_hour_window": metrics["p_positive_hour_window"],
            "p_profitable_block_window": metrics["p_profitable_block_window"],
            "cvar_hourly_window": metrics["cvar_hourly_window"],
            "cvar_nightly_mean": metrics["cvar_nightly_mean"],
            "n_hours_window": len(metrics["window_hourly"]),
            "n_nights": len(metrics["nightly_blocks"]),
        })

    summary_df = (
        pd.DataFrame(summary_rows)
        .set_index("iso_hub")
        .sort_values("sharpe_like_window", ascending=False)
    )

    print("\n=== Cross-ISO Summary (EV window) ===")
    print(summary_df)

    return all_metrics, summary_df, nightly_dict


# =========================================================
# 4) GROUP-AVERAGE best-fit plotting (ONLY 2 curves: zones vs hubs)
#    "Average curve" here means: pool data across the group and fit 1 dist.
# =========================================================
def plot_group_average_best_fit(
    all_metrics: dict,
    groups: dict,
    which="hourly",
    xlim=(-20, 20),
    npoints=800,
    criterion="AIC",
    hide_exact_zeros=True,
    zero_tol=0.0,
    min_n=200,
    candidates=("t", "skewnorm", "norm", "johnsonsu"),
):
    dist_map = {
        "norm": stats.norm,
        "t": stats.t,
        "skewnorm": stats.skewnorm,
        "johnsonsu": stats.johnsonsu,
    }
    candidates = [c for c in candidates if c in dist_map]
    if not candidates:
        raise ValueError("No valid candidates. Use one of: " + ", ".join(dist_map.keys()))
    if criterion not in ("AIC", "BIC"):
        raise ValueError("criterion must be 'AIC' or 'BIC'")

    def _get_series(m):
        if which == "hourly":
            return m["window_hourly"]["DA_minus_RT"].dropna()
        if which == "nightly":
            return m["nightly_blocks"]["night_mean"].dropna()
        raise ValueError("which must be 'hourly' or 'nightly'")

    def _filter_for_fit(s):
        x = np.asarray(s, dtype=float)
        x = x[np.isfinite(x)]
        if not hide_exact_zeros:
            return x
        if zero_tol == 0.0:
            return x[x != 0.0]
        return x[np.abs(x) > zero_tol]

    def _fit_and_score(dist, x):
        params = dist.fit(x)
        logpdf = dist.logpdf(x, *params)
        if not np.all(np.isfinite(logpdf)):
            return None
        ll = float(np.sum(logpdf))
        k = len(params)
        n = len(x)
        aic = 2 * k - 2 * ll
        bic = k * np.log(n) - 2 * ll
        return {"params": params, "ll": ll, "AIC": aic, "BIC": bic}

    # ---- pool samples per group ----
    pooled = {}
    for gname, selector in groups.items():
        xs = []
        for name, m in all_metrics.items():
            if selector(name):
                xs.append(_get_series(m))
        if xs:
            pooled[gname] = _filter_for_fit(pd.concat(xs, axis=0))

    # ---- fit best per group ----
    fits = {}
    for gname, x in pooled.items():
        if len(x) < min_n:
            print(f"[SKIP] {gname}: not enough samples (n={len(x)} < {min_n})")
            continue

        best_row = None
        for dname in candidates:
            dist = dist_map[dname]
            try:
                row = _fit_and_score(dist, x)
                if row is None:
                    continue
                row["dist_name"] = dname
                if (best_row is None) or (row[criterion] < best_row[criterion]):
                    best_row = row
            except Exception:
                continue

        if best_row is None:
            print(f"[FAIL] {gname}: all fits failed")
            continue

        fits[gname] = best_row
        print(f"[{gname}] best={best_row['dist_name']} | n={len(x)} | AIC={best_row['AIC']:.1f} | BIC={best_row['BIC']:.1f}")

    if not fits:
        print("No group had enough data (or all fits failed).")
        return

    # ---- plot ONLY group curves ----
    xx = np.linspace(xlim[0], xlim[1], npoints)
    plt.figure(figsize=(14, 7))

    for gname, row in fits.items():
        dist = dist_map[row["dist_name"]]
        pdf = dist.pdf(xx, *row["params"])
        if np.all(np.isfinite(pdf)):
            plt.plot(xx, pdf, linewidth=2, label=gname)

    plt.axvline(0, color="black", linestyle="--", linewidth=1)
    plt.xlim(*xlim)
    plt.xlabel("DART = DA − RT ($/MWh)" if which == "hourly" else "Nightly mean DART ($/MWh)")
    plt.ylabel("Density")
    plt.title("Averaged Hubs DART Spreads")
    plt.grid(True, linestyle=":")
    plt.legend(fontsize=10)
    plt.tight_layout()
    plt.show()


# =========================================================
# 5) CASES (YOUR PJM HUBS)
# =========================================================
CASES = [
    ("CAISO DLAP_PGAE-APND",
     p("DA_LMPs_Data","CAISO","df_DA_CAISO_DLAP_PGAE-APND_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","CAISO","df_RT_CAISO_DLAP_PGAE-APND_2025_RT_5min.csv"),
     "America/Los_Angeles"),

    ("CAISO DLAP_SCE-APND",
     p("DA_LMPs_Data","CAISO","df_DA_CAISO_DLAP_SCE-APND_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","CAISO","df_RT_CAISO_DLAP_SCE-APND_2025_RT_5min.csv"),
     "America/Los_Angeles"),

    ("CAISO DLAP_SDGE-APND",
     p("DA_LMPs_Data","CAISO","df_DA_CAISO_DLAP_SDGE-APND_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","CAISO","df_RT_CAISO_DLAP_SDGE-APND_2025_RT_5min.csv"),
     "America/Los_Angeles"),

    ("CAISO DLAP_VEA-APND",
     p("DA_LMPs_Data","CAISO","df_DA_CAISO_DLAP_VEA-APND_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","CAISO","df_RT_CAISO_DLAP_VEA-APND_2025_RT_5min.csv"),
     "America/Los_Angeles"),

        ("ERCOT AEN.LZ",
     p("DA_LMPs_Data","ERCOT","df_DA_ERCOT_AEN.LZ_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","ERCOT","df_RT_ERCOT_AEN.LZ_2025_RT_5min.csv"),
     "America/Chicago"),

     ("ERCOT CPS.LZ",
     p("DA_LMPs_Data","ERCOT","df_DA_ERCOT_CPS.LZ_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","ERCOT","df_RT_ERCOT_CPS.LZ_2025_RT_5min.csv"),
     "America/Chicago"),

     ("ERCOT LCRA.LZ",
     p("DA_LMPs_Data","ERCOT","df_DA_ERCOT_LCRA.LZ_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","ERCOT","df_RT_ERCOT_LCRA.LZ_2025_RT_5min.csv"),
     "America/Chicago"),

     ("ERCOT HOUSTON.LZ",
     p("DA_LMPs_Data","ERCOT","df_DA_ERCOT_HOUSTON.LZ_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","ERCOT","df_RT_ERCOT_HOUSTON.LZ_2025_RT_5min.csv"),
     "America/Chicago"),

     #("ERCOT HOUSTON.HUB",
     #p("DA_LMPs_Data","ERCOT","df_DA_ERCOT_HOUSTON.HUB_2025_DA_hourly.csv"),
     #p("RT_LMPs_Data","ERCOT","df_RT_ERCOT_HOUSTON.HUB_2025_RT_5min.csv"),
     #"America/Chicago"),

     #("ERCOT NORTH.HUB",
     #p("DA_LMPs_Data","ERCOT","df_DA_ERCOT_NORTH.HUB_2025_DA_hourly.csv"),
     #p("RT_LMPs_Data","ERCOT","df_RT_ERCOT_NORTH.HUB_2025_RT_5min.csv"),
     #"America/Chicago"),

     ("ERCOT NORTH.LZ",
     p("DA_LMPs_Data","ERCOT","df_DA_ERCOT_NORTH.LZ_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","ERCOT","df_RT_ERCOT_NORTH.LZ_2025_RT_5min.csv"),
     "America/Chicago"),

     ("ERCOT SOUTH.LZ",
     p("DA_LMPs_Data","ERCOT","df_DA_ERCOT_SOUTH.LZ_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","ERCOT","df_RT_ERCOT_SOUTH.LZ_2025_RT_5min.csv"),
     "America/Chicago"),

    #("ERCOT SOUTH.HUB",
     #p("DA_LMPs_Data","ERCOT","df_DA_ERCOT_SOUTH.HUB_2025_DA_hourly.csv"),
     #p("RT_LMPs_Data","ERCOT","df_RT_ERCOT_SOUTH.HUB_2025_RT_5min.csv"),
    #"America/Chicago"),

    ("ERCOT WEST.LZ",
     p("DA_LMPs_Data","ERCOT","df_DA_ERCOT_WEST.LZ_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","ERCOT","df_RT_ERCOT_WEST.LZ_2025_RT_5min.csv"),
     "America/Chicago"),

     #("ERCOT WEST.HUB",
     #p("DA_LMPs_Data","ERCOT","df_DA_ERCOT_WEST.HUB_2025_DA_hourly.csv"),
     #p("RT_LMPs_Data","ERCOT","df_RT_ERCOT_WEST.HUB_2025_RT_5min.csv"),
     #"America/Chicago"),

    #("ERCOT PAN.HUB",
     #p("DA_LMPs_Data","ERCOT","df_DA_ERCOT_PAN.HUB_2025_DA_hourly.csv"),
     #p("RT_LMPs_Data","ERCOT","df_RT_ERCOT_PAN.HUB_2025_RT_5min.csv"),
     #"America/Chicago"),

    ("ERCOT RAYBN.LZ",
     p("DA_LMPs_Data","ERCOT","df_DA_ERCOT_RAYBN.LZ_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","ERCOT","df_RT_ERCOT_RAYBN.LZ_2025_RT_5min.csv"),
     "America/Chicago"),

    ("ISO-NE Z.CONNECTICUT",
     p("DA_LMPs_Data","ISO-NE","df_DA_ISONE_Z.CONNECTICUT_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","ISO-NE","df_RT_ISONE_Z.CONNECTICUT_2025_RT_5min.csv"),
     "America/New_York"),

     ("ISO-NE Z.MAINE",
     p("DA_LMPs_Data","ISO-NE","df_DA_ISONE_Z.MAINE_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","ISO-NE","df_RT_ISONE_Z.MAINE_2025_RT_5min.csv"),
     "America/New_York"),

     ("ISO-NE Z.NEMASSBOST",
     p("DA_LMPs_Data","ISO-NE","df_DA_ISONE_Z.NEMASSBOST_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","ISO-NE","df_RT_ISONE_Z.NEMASSBOST_2025_RT_5min.csv"),
     "America/New_York"),

     ("ISO-NE Z.NEWHAMPSHIRE",
     p("DA_LMPs_Data","ISO-NE","df_DA_ISONE_Z.NEWHAMPSHIRE_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","ISO-NE","df_RT_ISONE_Z.NEWHAMPSHIRE_2025_RT_5min.csv"),
     "America/New_York"),

     ("ISO-NE Z.RHODEISLAND",
     p("DA_LMPs_Data","ISO-NE","df_DA_ISONE_Z.RHODEISLAND_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","ISO-NE","df_RT_ISONE_Z.RHODEISLAND_2025_RT_5min.csv"),
     "America/New_York"),

     ("ISO-NE Z.SEMASS",
     p("DA_LMPs_Data","ISO-NE","df_DA_ISONE_Z.SEMASS_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","ISO-NE","df_RT_ISONE_Z.SEMASS_2025_RT_5min.csv"),
     "America/New_York"),

     ("ISO-NE Z.VERMONT",
     p("DA_LMPs_Data","ISO-NE","df_DA_ISONE_Z.VERMONT_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","ISO-NE","df_RT_ISONE_Z.VERMONT_2025_RT_5min.csv"),
     "America/New_York"),

     ("ISO-NE Z.WCMASS",
     p("DA_LMPs_Data","ISO-NE","df_DA_ISONE_Z.WCMASS_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","ISO-NE","df_RT_ISONE_Z.WCMASS_2025_RT_5min.csv"),
     "America/New_York"),

    ("MISO ILLINOIS.HUB",
     p("DA_LMPs_Data","MISO","df_DA_MISO_ILLINOIS.HUB_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","MISO","df_RT_MISO_ILLINOIS.HUB_2025_RT_5min.csv"),
     "America/Chicago"),

    ("MISO ARKANSAS.HUB",
     p("DA_LMPs_Data","MISO","df_DA_MISO_ARKANSAS.HUB_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","MISO","df_RT_MISO_ARKANSAS.HUB_2025_RT_5min.csv"),
     "America/Chicago"),

    ("MISO INDIANA.HUB",
     p("DA_LMPs_Data","MISO","df_DA_MISO_INDIANA.HUB_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","MISO","df_RT_MISO_INDIANA.HUB_2025_RT_5min.csv"),
     "America/Chicago"),

    ("MISO LOUISIANA.HUB",
     p("DA_LMPs_Data","MISO","df_DA_MISO_LOUISIANA.HUB_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","MISO","df_RT_MISO_LOUISIANA.HUB_2025_RT_5min.csv"),
     "America/Chicago"),

    ("MISO MICHIGAN.HUB",
     p("DA_LMPs_Data","MISO","df_DA_MISO_MICHIGAN.HUB_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","MISO","df_RT_MISO_MICHIGAN.HUB_2025_RT_5min.csv"),
     "America/Chicago"),

    ("MISO MINN.HUB",
     p("DA_LMPs_Data","MISO","df_DA_MISO_MINN.HUB_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","MISO","df_RT_MISO_MINN.HUB_2025_RT_5min.csv"),
     "America/Chicago"),

    ("MISO MS.HUB",
     p("DA_LMPs_Data","MISO","df_DA_MISO_MS.HUB_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","MISO","df_RT_MISO_MS.HUB_2025_RT_5min.csv"),
     "America/Chicago"),

    ("MISO TEXAS.HUB",
     p("DA_LMPs_Data","MISO","df_DA_MISO_TEXAS.HUB_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","MISO","df_RT_MISO_TEXAS.HUB_2025_RT_5min.csv"),
     "America/Chicago"),
]


# =========================================================
# 6) SETTINGS + RUN
# =========================================================
START_HOUR = 0
END_HOUR   = 6
BLOCK_HOURS = 6
CVAR_ALPHA = 0.10
CLIP_LOW = -100
CLIP_HIGH = 100
PRICE_COL = "lmp"
RT_HOURLY_METHOD = "mean"

all_metrics, summary_df, nightly_dict = build_all_metrics_from_cases(
    CASES,
    START_HOUR=START_HOUR,
    END_HOUR=END_HOUR,
    BLOCK_HOURS=BLOCK_HOURS,
    CVAR_ALPHA=CVAR_ALPHA,
    CLIP_LOW=CLIP_LOW,
    CLIP_HIGH=CLIP_HIGH,
    PRICE_COL=PRICE_COL,
    RT_HOURLY_METHOD=RT_HOURLY_METHOD,
    verbose=False,
)

# =========================================================
# 7) PLOT ONLY TWO CURVES:
#    - "Zones" = NOT GEN HUB
#    - "Hubs"  = GEN HUB
# =========================================================
groups = {
    "CAISO LAPs": lambda name: any(s in name for s in ["DLAP"]),
    "ERCOT LZs": lambda name: any(s in name for s in ["AEN.LZ","CPS.LZ","LCRA.LZ","HOUSTON.LZ","NORTH.LZ","SOUTH.LZ","RAYBN.LZ"]),
    "ERCOT WEST.LZ": lambda name: any(s in name for s in ["WEST.LZ"]),
    "ISO-NE": lambda name: any(s in name for s in ["Z."]),
    "MISO Midwest Zones": lambda name: any(s in name for s in ["ILLINOIS.HUB","INDIANA.HUB","MICHIGAN.HUB",]),
    "MISO South Zones": lambda name: any(s in name for s in ["LOUISIANA.HUB","ARKANSAS.HUB","TEXAS.HUB","MS.HUB"]),
    "MISO Minnesota Zone": lambda name: any(s in name for s in ["MINN.HUB"]),    
}

plot_group_average_best_fit(
    all_metrics,
    groups=groups,
    which="hourly",
    xlim=(-20, 20),
    criterion="AIC",
    min_n=200,
)
# Out:
# BASE = C:\Users\hsofi\EVC\evc_project\bidding_strategy
#
# === Running: CAISO DLAP_PGAE-APND ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\CAISO\df_DA_CAISO_DLAP_PGAE-APND_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\CAISO\df_RT_CAISO_DLAP_PGAE-APND_2025_RT_5min.csv
#
# === Running: CAISO DLAP_SCE-APND ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\CAISO\df_DA_CAISO_DLAP_SCE-APND_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\CAISO\df_RT_CAISO_DLAP_SCE-APND_2025_RT_5min.csv
#
# === Running: CAISO DLAP_SDGE-APND ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\CAISO\df_DA_CAISO_DLAP_SDGE-APND_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\CAISO\df_RT_CAISO_DLAP_SDGE-APND_2025_RT_5min.csv
#
# === Running: CAISO DLAP_VEA-APND ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\CAISO\df_DA_CAISO_DLAP_VEA-APND_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\CAISO\df_RT_CAISO_DLAP_VEA-APND_2025_RT_5min.csv
#
# === Running: ERCOT AEN.LZ ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\ERCOT\df_DA_ERCOT_AEN.LZ_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\ERCOT\df_RT_ERCOT_AEN.LZ_2025_RT_5min.csv
#
# === Running: ERCOT CPS.LZ ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\ERCOT\df_DA_ERCOT_CPS.LZ_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\ERCOT\df_RT_ERCOT_CPS.LZ_2025_RT_5min.csv
#
# === Running: ERCOT LCRA.LZ ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\ERCOT\df_DA_ERCOT_LCRA.LZ_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\ERCOT\df_RT_ERCOT_LCRA.LZ_2025_RT_5min.csv
#
# === Running: ERCOT HOUSTON.LZ ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\ERCOT\df_DA_ERCOT_HOUSTON.LZ_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\ERCOT\df_RT_ERCOT_HOUSTON.LZ_2025_RT_5min.csv
#
# === Running: ERCOT NORTH.LZ ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\ERCOT\df_DA_ERCOT_NORTH.LZ_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\ERCOT\df_RT_ERCOT_NORTH.LZ_2025_RT_5min.csv
#
# === Running: ERCOT SOUTH.LZ ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\ERCOT\df_DA_ERCOT_SOUTH.LZ_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\ERCOT\df_RT_ERCOT_SOUTH.LZ_2025_RT_5min.csv
#
# === Running: ERCOT WEST.LZ ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\ERCOT\df_DA_ERCOT_WEST.LZ_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\ERCOT\df_RT_ERCOT_WEST.LZ_2025_RT_5min.csv
#
# === Running: ERCOT RAYBN.LZ ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\ERCOT\df_DA_ERCOT_RAYBN.LZ_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\ERCOT\df_RT_ERCOT_RAYBN.LZ_2025_RT_5min.csv
#
# === Running: ISO-NE Z.CONNECTICUT ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\ISO-NE\df_DA_ISONE_Z.CONNECTICUT_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\ISO-NE\df_RT_ISONE_Z.CONNECTICUT_2025_RT_5min.csv
#
# === Running: ISO-NE Z.MAINE ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\ISO-NE\df_DA_ISONE_Z.MAINE_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\ISO-NE\df_RT_ISONE_Z.MAINE_2025_RT_5min.csv
#
# === Running: ISO-NE Z.NEMASSBOST ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\ISO-NE\df_DA_ISONE_Z.NEMASSBOST_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\ISO-NE\df_RT_ISONE_Z.NEMASSBOST_2025_RT_5min.csv
#
# === Running: ISO-NE Z.NEWHAMPSHIRE ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\ISO-NE\df_DA_ISONE_Z.NEWHAMPSHIRE_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\ISO-NE\df_RT_ISONE_Z.NEWHAMPSHIRE_2025_RT_5min.csv
#
# === Running: ISO-NE Z.RHODEISLAND ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\ISO-NE\df_DA_ISONE_Z.RHODEISLAND_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\ISO-NE\df_RT_ISONE_Z.RHODEISLAND_2025_RT_5min.csv
#
# === Running: ISO-NE Z.SEMASS ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\ISO-NE\df_DA_ISONE_Z.SEMASS_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\ISO-NE\df_RT_ISONE_Z.SEMASS_2025_RT_5min.csv
#
# === Running: ISO-NE Z.VERMONT ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\ISO-NE\df_DA_ISONE_Z.VERMONT_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\ISO-NE\df_RT_ISONE_Z.VERMONT_2025_RT_5min.csv
#
# === Running: ISO-NE Z.WCMASS ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\ISO-NE\df_DA_ISONE_Z.WCMASS_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\ISO-NE\df_RT_ISONE_Z.WCMASS_2025_RT_5min.csv
#
# === Running: MISO ILLINOIS.HUB ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\MISO\df_DA_MISO_ILLINOIS.HUB_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\MISO\df_RT_MISO_ILLINOIS.HUB_2025_RT_5min.csv
#
# === Running: MISO ARKANSAS.HUB ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\MISO\df_DA_MISO_ARKANSAS.HUB_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\MISO\df_RT_MISO_ARKANSAS.HUB_2025_RT_5min.csv
#
# === Running: MISO INDIANA.HUB ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\MISO\df_DA_MISO_INDIANA.HUB_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\MISO\df_RT_MISO_INDIANA.HUB_2025_RT_5min.csv
#
# === Running: MISO LOUISIANA.HUB ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\MISO\df_DA_MISO_LOUISIANA.HUB_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\MISO\df_RT_MISO_LOUISIANA.HUB_2025_RT_5min.csv
#
# === Running: MISO MICHIGAN.HUB ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\MISO\df_DA_MISO_MICHIGAN.HUB_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\MISO\df_RT_MISO_MICHIGAN.HUB_2025_RT_5min.csv
#
# === Running: MISO MINN.HUB ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\MISO\df_DA_MISO_MINN.HUB_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\MISO\df_RT_MISO_MINN.HUB_2025_RT_5min.csv
#
# === Running: MISO MS.HUB ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\MISO\df_DA_MISO_MS.HUB_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\MISO\df_RT_MISO_MS.HUB_2025_RT_5min.csv
#
# === Running: MISO TEXAS.HUB ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\MISO\df_DA_MISO_TEXAS.HUB_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\MISO\df_RT_MISO_TEXAS.HUB_2025_RT_5min.csv
#
# === Cross-ISO Summary (EV window) ===
#                        mean_dart_window  std_dart_window  sharpe_like_window  \
# iso_hub
# MISO TEXAS.HUB                 1.852650         5.056099            0.366419
# MISO LOUISIANA.HUB             1.799729         5.344774            0.336727
# MISO ILLINOIS.HUB              2.200556         8.179078            0.269047
# MISO MS.HUB                    1.345972         5.342810            0.251922
# MISO ARKANSAS.HUB              1.602019         6.645482            0.241069
# CAISO DLAP_SDGE-APND           1.365860         7.045430            0.193865
# MISO INDIANA.HUB               1.412858         7.614812            0.185541
# MISO MINN.HUB                  2.038290        11.077520            0.184002
# CAISO DLAP_SCE-APND            1.121179         6.201979            0.180778
# MISO MICHIGAN.HUB              1.521718         8.531333            0.178368
# CAISO DLAP_PGAE-APND           1.086376         6.099485            0.178109
# CAISO DLAP_VEA-APND            0.855153         6.106621            0.140037
# ISO-NE Z.MAINE                 0.959758         9.229898            0.103984
# ERCOT CPS.LZ                   0.917052         9.221799            0.099444
# ISO-NE Z.VERMONT               0.799369         9.092894            0.087911
# ISO-NE Z.SEMASS                0.774880         8.965519            0.086429
# ISO-NE Z.NEMASSBOST            0.754514         8.991890            0.083910
# ISO-NE Z.NEWHAMPSHIRE          0.748266         9.003729            0.083106
# ISO-NE Z.WCMASS                0.734930         8.964712            0.081980
# ERCOT AEN.LZ                   0.713040         8.952407            0.079648
# ISO-NE Z.RHODEISLAND           0.709015         8.918295            0.079501
# ISO-NE Z.CONNECTICUT           0.657880         8.889025            0.074010
# ERCOT LCRA.LZ                  0.641720         9.307937            0.068943
# ERCOT RAYBN.LZ                 0.637616         9.425329            0.067649
# ERCOT NORTH.LZ                 0.567632         9.388940            0.060458
# ERCOT WEST.LZ                  0.868154        16.588875            0.052334
# ERCOT HOUSTON.LZ               0.371128         8.246964            0.045002
# ERCOT SOUTH.LZ                -0.024978         9.382014           -0.002662
#
#                        p_positive_hour_window  p_profitable_block_window  \
# iso_hub
# MISO TEXAS.HUB                       0.671861                   0.744485
# MISO LOUISIANA.HUB                   0.676444                   0.747243
# MISO ILLINOIS.HUB                    0.698442                   0.716452
# MISO MS.HUB                          0.630156                   0.692555
# MISO ARKANSAS.HUB                    0.639322                   0.698529
# CAISO DLAP_SDGE-APND                 0.645147                   0.666209
# MISO INDIANA.HUB                     0.672777                   0.707261
# MISO MINN.HUB                        0.654445                   0.703585
# CAISO DLAP_SCE-APND                  0.627289                   0.644689
# MISO MICHIGAN.HUB                    0.675985                   0.707261
# CAISO DLAP_PGAE-APND                 0.623626                   0.646520
# CAISO DLAP_VEA-APND                  0.605769                   0.626832
# ISO-NE Z.MAINE                       0.500916                   0.502289
# ERCOT CPS.LZ                         0.603022                   0.668040
# ISO-NE Z.VERMONT                     0.504579                   0.506410
# ISO-NE Z.SEMASS                      0.498626                   0.496337
# ISO-NE Z.NEMASSBOST                  0.495879                   0.493132
# ISO-NE Z.NEWHAMPSHIRE                0.495879                   0.497253
# ISO-NE Z.WCMASS                      0.497253                   0.494963
# ERCOT AEN.LZ                         0.604396                   0.667125
# ISO-NE Z.RHODEISLAND                 0.494505                   0.494048
# ISO-NE Z.CONNECTICUT                 0.501374                   0.501374
# ERCOT LCRA.LZ                        0.615385                   0.674908
# ERCOT RAYBN.LZ                       0.608974                   0.665293
# ERCOT NORTH.LZ                       0.609890                   0.666667
# ERCOT WEST.LZ                        0.539377                   0.556319
# ERCOT HOUSTON.LZ                     0.598443                   0.648810
# ERCOT SOUTH.LZ                       0.568681                   0.618590
#
#                        cvar_hourly_window  cvar_nightly_mean  n_hours_window  \
# iso_hub
# MISO TEXAS.HUB                  -4.629299          -3.274242            2184
# MISO LOUISIANA.HUB              -5.306909          -3.709831            2184
# MISO ILLINOIS.HUB              -12.347412          -8.099524            2184
# MISO MS.HUB                     -6.275630          -4.565515            2184
# MISO ARKANSAS.HUB               -7.100758          -5.507343            2184
# CAISO DLAP_SDGE-APND           -12.465811          -9.644215            2184
# MISO INDIANA.HUB               -13.243912          -8.165994            2184
# MISO MINN.HUB                  -19.695405         -15.063133            2184
# CAISO DLAP_SCE-APND            -11.139117          -8.641070            2184
# MISO MICHIGAN.HUB              -15.100192          -9.661411            2184
# CAISO DLAP_PGAE-APND           -10.959611          -8.473630            2184
# CAISO DLAP_VEA-APND            -11.065162          -8.827264            2184
# ISO-NE Z.MAINE                 -16.021606         -13.391234            2184
# ERCOT CPS.LZ                   -16.481593         -14.165423            2184
# ISO-NE Z.VERMONT               -16.178569         -13.366651            2184
# ISO-NE Z.SEMASS                -16.056777         -13.342431            2184
# ISO-NE Z.NEMASSBOST            -16.166785         -13.431341            2184
# ISO-NE Z.NEWHAMPSHIRE          -16.177264         -13.429861            2184
# ISO-NE Z.WCMASS                -16.126161         -13.374587            2184
# ERCOT AEN.LZ                   -16.794099         -14.886268            2184
# ISO-NE Z.RHODEISLAND           -16.044186         -13.327145            2184
# ISO-NE Z.CONNECTICUT           -16.069737         -13.297034            2184
# ERCOT LCRA.LZ                  -17.945935         -15.755913            2184
# ERCOT RAYBN.LZ                 -18.288400         -16.456695            2184
# ERCOT NORTH.LZ                 -18.422551         -16.690048            2184
# ERCOT WEST.LZ                  -29.888284         -25.834234            2184
# ERCOT HOUSTON.LZ               -16.231614         -14.742859            2184
# ERCOT SOUTH.LZ                 -18.987669         -16.745631            2184
#
#                        n_nights
# iso_hub
# MISO TEXAS.HUB              364
# MISO LOUISIANA.HUB          364
# MISO ILLINOIS.HUB           364
# MISO MS.HUB                 364
# MISO ARKANSAS.HUB           364
# CAISO DLAP_SDGE-APND        364
# MISO INDIANA.HUB            364
# MISO MINN.HUB               364
# CAISO DLAP_SCE-APND         364
# MISO MICHIGAN.HUB           364
# CAISO DLAP_PGAE-APND        364
# CAISO DLAP_VEA-APND         364
# ISO-NE Z.MAINE              364
# ERCOT CPS.LZ                364
# ISO-NE Z.VERMONT            364
# ISO-NE Z.SEMASS             364
# ISO-NE Z.NEMASSBOST         364
# ISO-NE Z.NEWHAMPSHIRE       364
# ISO-NE Z.WCMASS             364
# ERCOT AEN.LZ                364
# ISO-NE Z.RHODEISLAND        364
# ISO-NE Z.CONNECTICUT        364
# ERCOT LCRA.LZ               364
# ERCOT RAYBN.LZ              364
# ERCOT NORTH.LZ              364
# ERCOT WEST.LZ               364
# ERCOT HOUSTON.LZ            364
# ERCOT SOUTH.LZ              364
# [CAISO LAPs] best=johnsonsu | n=8733 | AIC=55671.3 | BIC=55699.6
# [ERCOT LZs] best=johnsonsu | n=15252 | AIC=101466.3 | BIC=101496.8
# [ERCOT WEST.LZ] best=johnsonsu | n=2169 | AIC=18316.4 | BIC=18339.1
# [ISO-NE] best=johnsonsu | n=15140 | AIC=105407.4 | BIC=105437.9
# [MISO Midwest Zones] best=johnsonsu | n=6536 | AIC=42498.7 | BIC=42525.8
# [MISO South Zones] best=johnsonsu | n=8727 | AIC=48007.4 | BIC=48035.7
# [MISO Minnesota Zone] best=johnsonsu | n=2182 | AIC=15792.9 | BIC=15815.7

# %%
# =========================================================
# DART EV-window metrics + GROUP-AVERAGE (PJM ZONES)
# Uses BASE = Path.cwd() + relative paths (NO C:\ hard-coding)
# =========================================================

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from pathlib import Path

BASE = Path.cwd()

def p(*parts) -> str:
    return str(BASE.joinpath(*parts))

# =========================================================
# 1) I/O helpers
# =========================================================
def load_table(path: str) -> pd.DataFrame:
    fp = Path(path)
    if not fp.exists():
        raise FileNotFoundError(
            f"File not found:\n{fp}\n\nBASE is:\n{BASE}\n"
            f"Tip: make sure DA_LMPs_Data/ and RT_LMPs_Data/ are inside BASE."
        )

    pth = path.lower()

    head = fp.read_bytes()[:2048]
    try:
        txt = head.decode("utf-8", errors="strict")
        if ("," in txt and "\n" in txt) or ("\t" in txt and "\n" in txt) or (";" in txt and "\n" in txt):
            delim_counts = {",": txt.count(","), "\t": txt.count("\t"), ";": txt.count(";")}
            sep = max(delim_counts, key=delim_counts.get)
            return pd.read_csv(path, sep=sep, low_memory=False)
    except Exception:
        pass

    if pth.endswith(".csv"):
        return pd.read_csv(path, low_memory=False)

    if pth.endswith((".xls", ".xlsx")):
        for engine in ["openpyxl", "xlrd"]:
            try:
                return pd.read_excel(path, engine=engine)
            except Exception:
                pass
        try:
            tables = pd.read_html(path)
            if tables:
                return tables[0]
        except Exception:
            pass
        raise ValueError(f"Excel file format cannot be determined for: {path}")

    raise ValueError(f"Unsupported file type: {path}")


def _get_time_col(df: pd.DataFrame) -> str:
    for c in [
        "interval_start_utc", "interval_start", "time", "timestamp", "datetime",
        "Interval Start", "IntervalStart", "interval_start_time_utc", "IntervalStartUTC"
    ]:
        if c in df.columns:
            return c
    for c in df.columns:
        try:
            if np.issubdtype(df[c].dtype, np.datetime64):
                return c
        except Exception:
            pass
    raise ValueError("No datetime column found. Columns:\n" + ", ".join(map(str, df.columns)))


def _pick_price_col(df: pd.DataFrame, preferred: str) -> str:
    if preferred in df.columns:
        return preferred

    lower_map = {str(c).lower(): c for c in df.columns}
    if preferred.lower() in lower_map:
        return lower_map[preferred.lower()]

    candidates = [
        "price", "lmp", "da_lmp", "rt_lmp",
        "lbmp", "mp", "value",
        "settlement_point_price", "settlement_point_price_dollar_per_mwh",
        "market_price"
    ]
    for c in candidates:
        if c in df.columns:
            return c
        if c.lower() in lower_map:
            return lower_map[c.lower()]

    numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
    for c in numeric_cols:
        if str(c).lower() not in {"year", "month", "day", "hour", "minute"}:
            return c

    raise KeyError(f"Could not find a price column. Columns are:\n{list(df.columns)}")


# =========================================================
# 2) Core: compute DART hourly (DA - RT hourly)
# =========================================================
def compute_dart_hourly(
    df_rt: pd.DataFrame,
    df_da: pd.DataFrame,
    price_col="lmp",
    clip_low=-100,
    clip_high=100,
    tz_plot="America/New_York",
    rt_hourly_method="mean",
    verbose=False,
) -> pd.DataFrame:
    rt_time_col = _get_time_col(df_rt)
    da_time_col = _get_time_col(df_da)
    rt_price_col = _pick_price_col(df_rt, price_col)
    da_price_col = _pick_price_col(df_da, price_col)

    if verbose:
        print(f"[RT] time col: '{rt_time_col}', price col: '{rt_price_col}'")
        print(f"[DA] time col: '{da_time_col}', price col: '{da_price_col}'")

    rt = df_rt[[rt_time_col, rt_price_col]].copy()
    rt[rt_time_col] = pd.to_datetime(rt[rt_time_col], utc=True, errors="coerce")
    rt = rt.dropna(subset=[rt_time_col, rt_price_col]).sort_values(rt_time_col)
    rt["ts"] = rt[rt_time_col].dt.tz_convert(tz_plot)
    rt["price"] = pd.to_numeric(rt[rt_price_col], errors="coerce").clip(lower=clip_low, upper=clip_high)
    rt = rt.dropna(subset=["price"]).set_index("ts")[["price"]]

    if rt_hourly_method == "mean":
        rt_h = rt.resample("h").mean()
    elif rt_hourly_method == "median":
        rt_h = rt.resample("h").median()
    elif rt_hourly_method == "last":
        rt_h = rt.resample("h").last()
    else:
        raise ValueError("rt_hourly_method must be one of: mean, median, last")
    rt_h = rt_h.rename(columns={"price": f"RT_hourly_{rt_hourly_method}"})

    da = df_da[[da_time_col, da_price_col]].copy()
    da[da_time_col] = pd.to_datetime(da[da_time_col], utc=True, errors="coerce")
    da = da.dropna(subset=[da_time_col, da_price_col]).sort_values(da_time_col)
    da["ts"] = da[da_time_col].dt.tz_convert(tz_plot)
    da["price"] = pd.to_numeric(da[da_price_col], errors="coerce").clip(lower=clip_low, upper=clip_high)
    da = da.dropna(subset=["price"]).set_index("ts")[["price"]].rename(columns={"price": "DA_hourly"})
    da_h = da.resample("h").mean()

    merged = da_h.join(rt_h, how="inner")
    merged["DA_minus_RT"] = merged["DA_hourly"] - merged[f"RT_hourly_{rt_hourly_method}"]
    return merged


def filter_charging_window(df: pd.DataFrame, start_hour=0, end_hour=6) -> pd.DataFrame:
    h = df.index.hour
    return df[(h >= start_hour) & (h < end_hour)]


def compute_ev_window_metrics(
    dart_hourly: pd.DataFrame,
    start_hour=0,
    end_hour=6,
    block_hours=6,
    cvar_alpha=0.10,
) -> dict:
    win = filter_charging_window(dart_hourly, start_hour, end_hour).copy()
    w = win["DA_minus_RT"].dropna()

    dart_hourly = dart_hourly.copy()
    dart_hourly["roll_mean"] = dart_hourly["DA_minus_RT"].rolling(block_hours).mean()
    dart_hourly["roll_std"]  = dart_hourly["DA_minus_RT"].rolling(block_hours).std()

    win["date_local"] = win.index.date
    nightly = win.groupby("date_local")["DA_minus_RT"].agg(["mean", "std", "count"])
    nightly = nightly.rename(columns={"mean": "night_mean", "std": "night_std", "count": "night_nhours"})

    mean_w = float(w.mean()) if len(w) else np.nan
    std_w  = float(w.std())  if len(w) else np.nan
    sharpe_like = (mean_w / std_w) if (std_w and std_w > 0) else np.nan

    p_pos_hour = float((w > 0).mean()) if len(w) else np.nan
    p_neg_hour = float((w < 0).mean()) if len(w) else np.nan

    roll_win = filter_charging_window(dart_hourly.dropna(subset=["roll_mean"]), start_hour, end_hour)
    roll_mean_avg = float(roll_win["roll_mean"].mean()) if len(roll_win) else np.nan
    p_pos_block   = float((roll_win["roll_mean"] > 0).mean()) if len(roll_win) else np.nan

    if len(w):
        q = w.quantile(cvar_alpha)
        cvar = float(w[w <= q].mean()) if np.isfinite(q) else np.nan
    else:
        cvar = np.nan

    if len(nightly) and nightly["night_mean"].notna().any():
        qn = nightly["night_mean"].quantile(cvar_alpha)
        cvar_night = float(nightly.loc[nightly["night_mean"] <= qn, "night_mean"].mean())
    else:
        cvar_night = np.nan

    return {
        "start_hour": start_hour,
        "end_hour": end_hour,
        "block_hours": block_hours,
        "cvar_alpha": cvar_alpha,

        "mean_dart_window": mean_w,
        "std_dart_window": std_w,
        "sharpe_like_window": sharpe_like,
        "p_positive_hour_window": p_pos_hour,
        "p_negative_hour_window": p_neg_hour,
        "cvar_hourly_window": cvar,

        "roll_mean_avg_window": roll_mean_avg,
        "p_profitable_block_window": p_pos_block,
        "cvar_nightly_mean": cvar_night,

        "dart_hourly": dart_hourly,
        "window_hourly": win,
        "nightly_blocks": nightly,
    }


# =========================================================
# 3) Build all_metrics from CASES
# =========================================================
def build_all_metrics_from_cases(
    CASES,
    START_HOUR=0,
    END_HOUR=6,
    BLOCK_HOURS=6,
    CVAR_ALPHA=0.10,
    CLIP_LOW=-100,
    CLIP_HIGH=100,
    PRICE_COL="lmp",
    RT_HOURLY_METHOD="mean",
    verbose=False,
    skip_missing=True,
):
    summary_rows = []
    nightly_dict = {}
    all_metrics = {}

    print("BASE =", BASE)

    for name, da_path, rt_path, tz in CASES:
        print(f"\n=== Running: {name} ===")
        print("DA:", da_path)
        print("RT:", rt_path)

        if skip_missing and (not Path(da_path).exists() or not Path(rt_path).exists()):
            print(f"!! Skipping (missing DA or RT file): {name}")
            continue

        df_DA = load_table(da_path)
        df_RT = load_table(rt_path)

        dart_hourly = compute_dart_hourly(
            df_rt=df_RT,
            df_da=df_DA,
            price_col=PRICE_COL,
            clip_low=CLIP_LOW,
            clip_high=CLIP_HIGH,
            tz_plot=tz,
            rt_hourly_method=RT_HOURLY_METHOD,
            verbose=verbose,
        )

        metrics = compute_ev_window_metrics(
            dart_hourly=dart_hourly,
            start_hour=START_HOUR,
            end_hour=END_HOUR,
            block_hours=BLOCK_HOURS,
            cvar_alpha=CVAR_ALPHA,
        )

        all_metrics[name] = metrics
        nightly_dict[name] = metrics["nightly_blocks"]

        summary_rows.append({
            "iso_hub": name,
            "mean_dart_window": metrics["mean_dart_window"],
            "std_dart_window": metrics["std_dart_window"],
            "sharpe_like_window": metrics["sharpe_like_window"],
            "p_positive_hour_window": metrics["p_positive_hour_window"],
            "p_profitable_block_window": metrics["p_profitable_block_window"],
            "cvar_hourly_window": metrics["cvar_hourly_window"],
            "cvar_nightly_mean": metrics["cvar_nightly_mean"],
            "n_hours_window": len(metrics["window_hourly"]),
            "n_nights": len(metrics["nightly_blocks"]),
        })

    summary_df = (
        pd.DataFrame(summary_rows)
        .set_index("iso_hub")
        .sort_values("sharpe_like_window", ascending=False)
    )

    print("\n=== Cross-ISO Summary (EV window) ===")
    print(summary_df)

    return all_metrics, summary_df, nightly_dict


# =========================================================
# 4) GROUP-AVERAGE best-fit plotting
# =========================================================
def plot_group_average_best_fit(
    all_metrics: dict,
    groups: dict,
    which="hourly",
    xlim=(-20, 20),
    npoints=800,
    criterion="AIC",
    hide_exact_zeros=True,
    zero_tol=0.0,
    min_n=200,
    candidates=("t", "skewnorm", "norm", "johnsonsu"),
    title="Averaged DART Spreads",
):
    dist_map = {
        "norm": stats.norm,
        "t": stats.t,
        "skewnorm": stats.skewnorm,
        "johnsonsu": stats.johnsonsu,
    }
    candidates = [c for c in candidates if c in dist_map]
    if not candidates:
        raise ValueError("No valid candidates. Use one of: " + ", ".join(dist_map.keys()))
    if criterion not in ("AIC", "BIC"):
        raise ValueError("criterion must be 'AIC' or 'BIC'")

    def _get_series(m):
        if which == "hourly":
            return m["window_hourly"]["DA_minus_RT"].dropna()
        if which == "nightly":
            return m["nightly_blocks"]["night_mean"].dropna()
        raise ValueError("which must be 'hourly' or 'nightly'")

    def _filter_for_fit(s):
        x = np.asarray(s, dtype=float)
        x = x[np.isfinite(x)]
        if not hide_exact_zeros:
            return x
        if zero_tol == 0.0:
            return x[x != 0.0]
        return x[np.abs(x) > zero_tol]

    def _fit_and_score(dist, x):
        params = dist.fit(x)
        logpdf = dist.logpdf(x, *params)
        if not np.all(np.isfinite(logpdf)):
            return None
        ll = float(np.sum(logpdf))
        k = len(params)
        n = len(x)
        aic = 2 * k - 2 * ll
        bic = k * np.log(n) - 2 * ll
        return {"params": params, "ll": ll, "AIC": aic, "BIC": bic}

    pooled = {}
    for gname, selector in groups.items():
        xs = []
        for name, m in all_metrics.items():
            if selector(name):
                xs.append(_get_series(m))
        if xs:
            pooled[gname] = _filter_for_fit(pd.concat(xs, axis=0))
        else:
            print(f"[WARN] {gname}: selector matched nothing")

    fits = {}
    for gname, x in pooled.items():
        if len(x) < min_n:
            print(f"[SKIP] {gname}: not enough samples (n={len(x)} < {min_n})")
            continue

        best_row = None
        for dname in candidates:
            dist = dist_map[dname]
            try:
                row = _fit_and_score(dist, x)
                if row is None:
                    continue
                row["dist_name"] = dname
                if (best_row is None) or (row[criterion] < best_row[criterion]):
                    best_row = row
            except Exception:
                continue

        if best_row is None:
            print(f"[FAIL] {gname}: all fits failed")
            continue

        fits[gname] = best_row
        print(f"[{gname}] best={best_row['dist_name']} | n={len(x)} | AIC={best_row['AIC']:.1f} | BIC={best_row['BIC']:.1f}")

    if not fits:
        print("No group had enough data (or all fits failed).")
        return

    xx = np.linspace(xlim[0], xlim[1], npoints)
    plt.figure(figsize=(14, 7))

    for gname, row in fits.items():
        dist = dist_map[row["dist_name"]]
        pdf = dist.pdf(xx, *row["params"])
        if np.all(np.isfinite(pdf)):
            plt.plot(xx, pdf, linewidth=2, label=gname)

    plt.axvline(0, color="black", linestyle="--", linewidth=1)
    plt.xlim(*xlim)
    plt.xlabel("DART = DA − RT ($/MWh)" if which == "hourly" else "Nightly mean DART ($/MWh)")
    plt.ylabel("Density")
    plt.title(title)
    plt.grid(True, linestyle=":")
    plt.legend(fontsize=10)
    plt.tight_layout()
    plt.show()


# =========================================================
# 5) CASES (PJM ZONES)  <-- ONLY THIS SECTION CHANGED
#    NOTE: Use "PJM_RTO" (underscore) not "PJM-RTO" in filenames (based on your error).
# =========================================================
PJM_ZONES = [
    "AECO","AEP","APS","ATSI","BGE","COMED","DAY","DEOK","DOM","DPL","DUQ","EKPC",
    "JCPL","METED","OVEC","PECO","PENELEC","PEPCO","PPL","PSEG","RECO","PJM-RTO"
]

PJM_CASES = [
    (f"PJM {z}",
     p("DA_LMPs_Data","PJM", f"df_DA_PJM_{z}_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","PJM", f"df_RT_PJM_{z}_2025_RT_5min.csv"),
     "America/New_York")
    for z in PJM_ZONES
]

NYISO_CASES = [
    ("NYISO CAPITL",
     p("DA_LMPs_Data","NYISO","df_DA_NYISO_CAPITL_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","NYISO","df_RT_NYISO_CAPITL_2025_RT_5min.csv"),
     "America/New_York"),

    ("NYISO CENTRL",
     p("DA_LMPs_Data","NYISO","df_DA_NYISO_CENTRL_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","NYISO","df_RT_NYISO_CENTRL_2025_RT_5min.csv"),
     "America/New_York"),

    ("NYISO DUNWOD",
     p("DA_LMPs_Data","NYISO","df_DA_NYISO_DUNWOD_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","NYISO","df_RT_NYISO_DUNWOD_2025_RT_5min.csv"),
     "America/New_York"),

    ("NYISO GENESE",
     p("DA_LMPs_Data","NYISO","df_DA_NYISO_GENESE_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","NYISO","df_RT_NYISO_GENESE_2025_RT_5min.csv"),
     "America/New_York"),

    ("NYISO HUD VL",
     p("DA_LMPs_Data","NYISO","df_DA_NYISO_HUD VL_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","NYISO","df_RT_NYISO_HUD VL_2025_RT_5min.csv"),
     "America/New_York"),

    ("NYISO LONGIL",
     p("DA_LMPs_Data","NYISO","df_DA_NYISO_LONGIL_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","NYISO","df_RT_NYISO_LONGIL_2025_RT_5min.csv"),
     "America/New_York"),

    ("NYISO MHK VL",
     p("DA_LMPs_Data","NYISO","df_DA_NYISO_MHK VL_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","NYISO","df_RT_NYISO_MHK VL_2025_RT_5min.csv"),
     "America/New_York"),

    ("NYISO MILLWD",
     p("DA_LMPs_Data","NYISO","df_DA_NYISO_MILLWD_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","NYISO","df_RT_NYISO_MILLWD_2025_RT_5min.csv"),
     "America/New_York"),

    ("NYISO N.Y.C.",
     p("DA_LMPs_Data","NYISO","df_DA_NYISO_N.Y.C._2025_DA_hourly.csv"),
     p("RT_LMPs_Data","NYISO","df_RT_NYISO_N.Y.C._2025_RT_5min.csv"),
     "America/New_York"),

    ("NYISO NORTH",
     p("DA_LMPs_Data","NYISO","df_DA_NYISO_NORTH_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","NYISO","df_RT_NYISO_NORTH_2025_RT_5min.csv"),
     "America/New_York"),

    ("NYISO WEST",
     p("DA_LMPs_Data","NYISO","df_DA_NYISO_WEST_2025_DA_hourly.csv"),
     p("RT_LMPs_Data","NYISO","df_RT_NYISO_WEST_2025_RT_5min.csv"),
     "America/New_York"),
]

CASES = PJM_CASES + NYISO_CASES
# =========================================================
# 6) SETTINGS + RUN
# =========================================================
START_HOUR = 0
END_HOUR   = 6
BLOCK_HOURS = 6
CVAR_ALPHA = 0.10
CLIP_LOW = -100
CLIP_HIGH = 100
PRICE_COL = "lmp"
RT_HOURLY_METHOD = "mean"

all_metrics, summary_df, nightly_dict = build_all_metrics_from_cases(
    CASES,
    START_HOUR=START_HOUR,
    END_HOUR=END_HOUR,
    BLOCK_HOURS=BLOCK_HOURS,
    CVAR_ALPHA=CVAR_ALPHA,
    CLIP_LOW=CLIP_LOW,
    CLIP_HIGH=CLIP_HIGH,
    PRICE_COL=PRICE_COL,
    RT_HOURLY_METHOD=RT_HOURLY_METHOD,
    verbose=False,
    skip_missing=True,
)

# =========================================================
# GROUPS (edit to your needs)
# =========================================================
groups = {
    "PJM Other Zones": lambda name: any(s in name for s in ["AECO", "APS","AEP", "ATSI", "DAY","DEOK", "DPL", "DUQ","EKPC", "JCPL", "METED","PECO","OVEC", "PJM-RTO", "PPL", "PSEG","PENELEC","BGE","RECO","PEPCO","DOM"]),      
    "PJM COMED": lambda name: any(s in name for s in ["COMED"]),
    "NYISO North Zone": lambda name: any(s in name for s in ["NORTH"]),
    "NYISO Long Island": lambda name: any(s in name for s in ["LONGIL"]),
    "NYISO Other Zones ": lambda name: any(s in name for s in ["CAPITL","CENTRL","DUNWOD", "GENESE","HUD VL","MHK VL","MILLWD","N.Y.C.","WEST"]),    
}

plot_group_average_best_fit(
    all_metrics,
    groups=groups,
    which="hourly",
    xlim=(-20, 20),
    criterion="AIC",
    min_n=200,
    title="Averaged Zones DART Spreads",
)
# Out:
# BASE = C:\Users\hsofi\EVC\evc_project\bidding_strategy
#
# === Running: PJM AECO ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\PJM\df_DA_PJM_AECO_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\PJM\df_RT_PJM_AECO_2025_RT_5min.csv
#
# === Running: PJM AEP ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\PJM\df_DA_PJM_AEP_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\PJM\df_RT_PJM_AEP_2025_RT_5min.csv
#
# === Running: PJM APS ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\PJM\df_DA_PJM_APS_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\PJM\df_RT_PJM_APS_2025_RT_5min.csv
#
# === Running: PJM ATSI ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\PJM\df_DA_PJM_ATSI_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\PJM\df_RT_PJM_ATSI_2025_RT_5min.csv
#
# === Running: PJM BGE ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\PJM\df_DA_PJM_BGE_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\PJM\df_RT_PJM_BGE_2025_RT_5min.csv
#
# === Running: PJM COMED ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\PJM\df_DA_PJM_COMED_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\PJM\df_RT_PJM_COMED_2025_RT_5min.csv
#
# === Running: PJM DAY ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\PJM\df_DA_PJM_DAY_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\PJM\df_RT_PJM_DAY_2025_RT_5min.csv
#
# === Running: PJM DEOK ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\PJM\df_DA_PJM_DEOK_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\PJM\df_RT_PJM_DEOK_2025_RT_5min.csv
#
# === Running: PJM DOM ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\PJM\df_DA_PJM_DOM_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\PJM\df_RT_PJM_DOM_2025_RT_5min.csv
#
# === Running: PJM DPL ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\PJM\df_DA_PJM_DPL_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\PJM\df_RT_PJM_DPL_2025_RT_5min.csv
#
# === Running: PJM DUQ ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\PJM\df_DA_PJM_DUQ_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\PJM\df_RT_PJM_DUQ_2025_RT_5min.csv
#
# === Running: PJM EKPC ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\PJM\df_DA_PJM_EKPC_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\PJM\df_RT_PJM_EKPC_2025_RT_5min.csv
#
# === Running: PJM JCPL ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\PJM\df_DA_PJM_JCPL_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\PJM\df_RT_PJM_JCPL_2025_RT_5min.csv
#
# === Running: PJM METED ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\PJM\df_DA_PJM_METED_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\PJM\df_RT_PJM_METED_2025_RT_5min.csv
#
# === Running: PJM OVEC ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\PJM\df_DA_PJM_OVEC_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\PJM\df_RT_PJM_OVEC_2025_RT_5min.csv
#
# === Running: PJM PECO ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\PJM\df_DA_PJM_PECO_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\PJM\df_RT_PJM_PECO_2025_RT_5min.csv
#
# === Running: PJM PENELEC ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\PJM\df_DA_PJM_PENELEC_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\PJM\df_RT_PJM_PENELEC_2025_RT_5min.csv
#
# === Running: PJM PEPCO ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\PJM\df_DA_PJM_PEPCO_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\PJM\df_RT_PJM_PEPCO_2025_RT_5min.csv
#
# === Running: PJM PPL ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\PJM\df_DA_PJM_PPL_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\PJM\df_RT_PJM_PPL_2025_RT_5min.csv
#
# === Running: PJM PSEG ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\PJM\df_DA_PJM_PSEG_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\PJM\df_RT_PJM_PSEG_2025_RT_5min.csv
#
# === Running: PJM RECO ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\PJM\df_DA_PJM_RECO_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\PJM\df_RT_PJM_RECO_2025_RT_5min.csv
#
# === Running: PJM PJM-RTO ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\PJM\df_DA_PJM_PJM-RTO_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\PJM\df_RT_PJM_PJM-RTO_2025_RT_5min.csv
#
# === Running: NYISO CAPITL ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\NYISO\df_DA_NYISO_CAPITL_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\NYISO\df_RT_NYISO_CAPITL_2025_RT_5min.csv
#
# === Running: NYISO CENTRL ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\NYISO\df_DA_NYISO_CENTRL_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\NYISO\df_RT_NYISO_CENTRL_2025_RT_5min.csv
#
# === Running: NYISO DUNWOD ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\NYISO\df_DA_NYISO_DUNWOD_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\NYISO\df_RT_NYISO_DUNWOD_2025_RT_5min.csv
#
# === Running: NYISO GENESE ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\NYISO\df_DA_NYISO_GENESE_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\NYISO\df_RT_NYISO_GENESE_2025_RT_5min.csv
#
# === Running: NYISO HUD VL ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\NYISO\df_DA_NYISO_HUD VL_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\NYISO\df_RT_NYISO_HUD VL_2025_RT_5min.csv
#
# === Running: NYISO LONGIL ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\NYISO\df_DA_NYISO_LONGIL_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\NYISO\df_RT_NYISO_LONGIL_2025_RT_5min.csv
#
# === Running: NYISO MHK VL ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\NYISO\df_DA_NYISO_MHK VL_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\NYISO\df_RT_NYISO_MHK VL_2025_RT_5min.csv
#
# === Running: NYISO MILLWD ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\NYISO\df_DA_NYISO_MILLWD_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\NYISO\df_RT_NYISO_MILLWD_2025_RT_5min.csv
#
# === Running: NYISO N.Y.C. ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\NYISO\df_DA_NYISO_N.Y.C._2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\NYISO\df_RT_NYISO_N.Y.C._2025_RT_5min.csv
#
# === Running: NYISO NORTH ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\NYISO\df_DA_NYISO_NORTH_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\NYISO\df_RT_NYISO_NORTH_2025_RT_5min.csv
#
# === Running: NYISO WEST ===
# DA: C:\Users\hsofi\EVC\evc_project\bidding_strategy\DA_LMPs_Data\NYISO\df_DA_NYISO_WEST_2025_DA_hourly.csv
# RT: C:\Users\hsofi\EVC\evc_project\bidding_strategy\RT_LMPs_Data\NYISO\df_RT_NYISO_WEST_2025_RT_5min.csv
#
# === Cross-ISO Summary (EV window) ===
#               mean_dart_window  std_dart_window  sharpe_like_window  \
# iso_hub
# PJM BGE               3.131904        10.088381            0.310447
# PJM PEPCO             2.809606         9.676681            0.290348
# PJM DOM               2.539177        11.530095            0.220222
# PJM ATSI              1.497922         7.810727            0.191778
# PJM DAY               1.555245         8.518648            0.182569
# PJM APS               1.446519         7.976542            0.181347
# PJM DEOK              1.550069         8.641549            0.179374
# PJM OVEC              1.790957        10.476011            0.170958
# PJM DPL               1.587109         9.474502            0.167514
# PJM PENELEC           1.437195         9.240681            0.155529
# PJM AEP               1.136477         7.870349            0.144400
# PJM PJM-RTO           1.109060         7.927295            0.139904
# PJM PPL               1.035133         7.641780            0.135457
# PJM EKPC              1.022861         7.726092            0.132390
# PJM METED             1.080995         8.171129            0.132294
# PJM AECO              0.972245         7.431771            0.130823
# PJM PECO              0.989284         7.564920            0.130773
# PJM DUQ               0.950740         7.671556            0.123931
# PJM RECO              1.009975         8.384528            0.120457
# PJM JCPL              0.871635         7.278525            0.119754
# NYISO LONGIL          1.056581        10.149711            0.104100
# NYISO WEST            1.078228        10.643397            0.101305
# NYISO NORTH           1.136008        12.291472            0.092422
# NYISO CAPITL          0.878667         9.728559            0.090318
# PJM PSEG              0.647127         7.383585            0.087644
# PJM COMED             0.984350        12.043522            0.081733
# NYISO DUNWOD          0.737237         9.065272            0.081325
# NYISO HUD VL          0.743106         9.141689            0.081288
# NYISO MILLWD          0.741127         9.192991            0.080619
# NYISO MHK VL          0.766967         9.937369            0.077180
# NYISO N.Y.C.          0.603218         8.943886            0.067445
# NYISO GENESE          0.586298        10.327010            0.056773
# NYISO CENTRL          0.505942        10.138611            0.049903
#
#               p_positive_hour_window  p_profitable_block_window  \
# iso_hub
# PJM BGE                     0.692766                   0.729779
# PJM PEPCO                   0.687729                   0.709099
# PJM DOM                     0.673077                   0.707721
# PJM ATSI                    0.655678                   0.673254
# PJM DAY                     0.632784                   0.664982
# PJM APS                     0.652015                   0.660386
# PJM DEOK                    0.638278                   0.668658
# PJM OVEC                    0.631410                   0.645221
# PJM DPL                     0.618590                   0.651654
# PJM PENELEC                 0.635073                   0.638787
# PJM AEP                     0.637821                   0.654412
# PJM PJM-RTO                 0.616300                   0.654412
# PJM PPL                     0.603480                   0.649816
# PJM EKPC                    0.604396                   0.636949
# PJM METED                   0.623168                   0.653033
# PJM AECO                    0.621795                   0.641085
# PJM PECO                    0.620421                   0.633732
# PJM DUQ                     0.630037                   0.637408
# PJM RECO                    0.598443                   0.621324
# PJM JCPL                    0.615842                   0.634191
# NYISO LONGIL                0.543956                   0.605769
# NYISO WEST                  0.535256                   0.586081
# NYISO NORTH                 0.498168                   0.549908
# NYISO CAPITL                0.534341                   0.596612
# PJM PSEG                    0.581960                   0.612132
# PJM COMED                   0.492216                   0.549173
# NYISO DUNWOD                0.534341                   0.595696
# NYISO HUD VL                0.532051                   0.592033
# NYISO MILLWD                0.536630                   0.597985
# NYISO MHK VL                0.519231                   0.567766
# NYISO N.Y.C.                0.523352                   0.578297
# NYISO GENESE                0.508242                   0.566392
# NYISO CENTRL                0.502747                   0.557234
#
#               cvar_hourly_window  cvar_nightly_mean  n_hours_window  n_nights
# iso_hub
# PJM BGE               -14.623030          -9.357095            2184       364
# PJM PEPCO             -14.414263          -9.171048            2184       364
# PJM DOM               -17.945603         -13.018700            2184       364
# PJM ATSI              -13.304363          -7.980817            2184       364
# PJM DAY               -13.733794          -8.468134            2184       364
# PJM APS               -14.098469          -8.567763            2184       364
# PJM DEOK              -14.018198          -8.837420            2184       364
# PJM OVEC              -14.087777          -8.652244            2184       364
# PJM DPL               -12.919651          -9.187565            2184       364
# PJM PENELEC           -16.392722         -10.438406            2184       364
# PJM AEP               -14.534023          -8.599079            2184       364
# PJM PJM-RTO           -13.882825          -9.080059            2184       364
# PJM PPL               -12.546266          -8.729670            2184       364
# PJM EKPC              -13.540879          -7.890955            2184       364
# PJM METED             -13.716580          -9.383268            2184       364
# PJM AECO              -11.991268          -8.059160            2184       364
# PJM PECO              -12.186526          -8.152505            2184       364
# PJM DUQ               -14.106059          -8.616147            2184       364
# PJM RECO              -14.404845          -9.127880            2184       364
# PJM JCPL              -12.012438          -8.047922            2184       364
# NYISO LONGIL          -17.618162         -14.557650            2184       364
# NYISO WEST            -17.094809         -13.948293            2184       364
# NYISO NORTH           -18.091625         -14.566937            2184       364
# NYISO CAPITL          -16.589809         -14.033219            2184       364
# PJM PSEG              -12.434423          -8.385494            2184       364
# PJM COMED             -17.634680         -13.409848            2184       364
# NYISO DUNWOD          -15.777546         -12.988117            2184       364
# NYISO HUD VL          -15.781069         -13.140224            2184       364
# NYISO MILLWD          -16.069280         -13.293767            2184       364
# NYISO MHK VL          -16.343546         -13.301202            2184       364
# NYISO N.Y.C.          -15.795667         -13.061783            2184       364
# NYISO GENESE          -17.573411         -14.343944            2184       364
# NYISO CENTRL          -17.388256         -14.342628            2184       364
# [PJM Other Zones] best=johnsonsu | n=45655 | AIC=300887.1 | BIC=300922.1
# [PJM COMED] best=johnsonsu | n=2184 | AIC=15996.3 | BIC=16019.0
# [NYISO North Zone] best=johnsonsu | n=2125 | AIC=15815.4 | BIC=15838.0
# [NYISO Long Island] best=johnsonsu | n=2080 | AIC=15185.0 | BIC=15207.6
# [NYISO Other Zones ] best=johnsonsu | n=18988 | AIC=134808.3 | BIC=134839.7
